# %% [markdown]
# <a href="https://colab.research.google.com/github/Ridzzz0Alam/Data_Science/blob/main/Assignment_on_Module_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assignment on Module 1
#
# Assignment: 1
#
# Loops Strings and Smart Operations

# %% [markdown]
# Problem: 01
#
# Write a Python program that takes a number as input and checks whether it is even or odd.

# %%
num=int(input("Enter the number you want to check: "))

if num%2==0:
  print(f"{num} is Even")
else:
  print(f"{num} is Odd")
# Out:
# Enter the number you want to check: 5
# 5 is Odd

# %% [markdown]
# Problem: 02
#
# Write a program that takes two numbers and an operator (+, -, *, /) and performs the calculation.

# %%
num1=float(input("Enter the first number: "))
num2=float(input("Enter the second number: "))
operator=input("Enter the operation you want to perform (+, -, *, /): ")

if operator=="+":
  result=num1+num2
elif operator=="-":
  result=num1-num2
elif operator=="*":
  result=num1*num2
elif operator=="/":
  if num!=0:
    result=num1/num2
  else:
    print("Cannot divide by zero")
    result=None
else:
  print("Invalid Operator")

print(f"Result: {result}")
# Out:
# Enter the first number: 10
# Enter the second number: 15
# Enter the operation you want to perform (+, -, *, /): /
# Result: 0.6666666666666666

# %% [markdown]
# Problem: 03
#
# Write a program using a for loop that calculates the sum of even numbers between 1 and 100.

# %%
total=0
for i in range(1,100):
  if i%2==0:
    total+=i
print(f"The sum of even numbers between 1 and 100 is: {total}")
# Out:
# The sum of even numbers between 1 and 100 is: 2450
