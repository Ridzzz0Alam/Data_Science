# %% [markdown]
# <a href="https://colab.research.google.com/github/Ridzzz0Alam/Data_Science/blob/main/DTree_Project_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Reading the data file in df

# %% [markdown]
# **Read the csv data file and disply its head**

# %%
# Code here please

# %%
df = pd.read_csv("mammographic_masses_data_clean.csv")
df.head()
# Out:
#    BI-RADS  Age  Shape  Margin  Density  Target
# 0        5   67      3       5        3       1
# 1        5   58      4       5        3       1
# 2        4   28      1       1        3       0
# 3        5   57      1       5        3       1
# 4        5   76      1       4        3       1

# %% [markdown]
# **How many data entries you have?**

# %%
# Code here please

# %%
df.describe()
# Out:
#           BI-RADS         Age       Shape      Margin     Density      Target
# count  830.000000  830.000000  830.000000  830.000000  830.000000  830.000000
# mean     4.393976   55.781928    2.781928    2.813253    2.915663    0.485542
# std      1.888371   14.671782    1.242361    1.567175    0.350936    0.500092
# min      0.000000   18.000000    1.000000    1.000000    1.000000    0.000000
# 25%      4.000000   46.000000    2.000000    1.000000    3.000000    0.000000
# 50%      4.000000   57.000000    3.000000    3.000000    3.000000    0.000000
# 75%      5.000000   66.000000    4.000000    4.000000    3.000000    1.000000
# max     55.000000   96.000000    4.000000    5.000000    4.000000    1.000000

# %% [markdown]
# **Which type of cancer is common?**

# %%
df.isnull().sum()
# Out:
# BI-RADS    0
# Age        0
# Shape      0
# Margin     0
# Density    0
# Target     0
# dtype: int64

# %%
sns.countplot(x='Target', data=df)
plt.title("Target Distribution")
plt.show()

# %%
# Out:
# 0    427
# 1    403
# Name: Target, dtype: int64

# %% [markdown]
# **Reproduce the output to show some statistics**

# %%
# Code here please

# %%
X = df.drop("Target", axis=1)
y = df["Target"]

# %% [markdown]
# ** Do the Train Test Split** using test size 0.3

# %%
# Code here please

# %%
# Code here please

# %%
# Code here please

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %% [markdown]
# ### Decision Tree
# **Importing decision tree classifier and create its instance**

# %%
# Code here please

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(criterion="gini", max_depth=4, random_state=42)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=42)

# %% [markdown]
# **Fit the training data to the model**

# %%
# Code here please

# %%
model
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=42)

# %% [markdown]
# **What is the Score of the model?**

# %%
# Code here please

# %%
model.score(X_test, y_test)
# Out:
# 0.8112449799196787
